# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/credit_card_db')

# %%
raw_data = pd.read_csv("Resources/CC GENERAL.csv")
raw_data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
renamed_df = raw_data.rename(columns={"CUST_ID": "customer_id",
                                      "BALANCE": "balance",
                                      "BALANCE_FREQUENCY":"balance_change_frequency",
                                      "PURCHASES": "number_of_purchases",
                                      "ONEOFF_PURCHASES":"oneoff_purchases",
                                      "INSTALLMENTS_PURCHASES":"installment_purchases",
                                      "CASH_ADVANCE":"amount_cash_advance",
                                      "PURCHASES_FREQUENCY":"purchases_frequency",
                                      "ONEOFF_PURCHASES_FREQUENCY":"oneoff_purchases_frequency",
                                      "PURCHASES_INSTALLMENTS_FREQUENCY":"installment_purchase_frequency",
                                      "CASH_ADVANCE_FREQUENCY":"cash_advance_frequency",
                                      "CASH_ADVANCE_TRX":"cash_advance_transactions",
                                      "PURCHASES_TRX":"purchase_transactions",
                                      "CREDIT_LIMIT":"credit_limit",
                                      "PAYMENTS":"amount_of_payments",
                                      "MINIMUM_PAYMENTS":"minimum_payments_made",
                                      "PRC_FULL_PAYMENT":"pct_of_full_payments",
                                      "TENURE":"tenure"})
renamed_df
# Out:
#      customer_id      balance  balance_change_frequency  number_of_purchases  \
# 0         C10001    40.900749                  0.818182                95.40
# 1         C10002  3202.467416                  0.909091                 0.00
# 2         C10003  2495.148862                  1.000000               773.17
# 3         C10004  1666.670542                  0.636364              1499.00
# 4         C10005   817.714335                  1.000000                16.00
# ...          ...          ...                       ...                  ...
# 8945      C19186    28.493517                  1.000000               291.12
# 8946      C19187    19.183215                  1.000000               300.00
# 8947      C19188    23.398673                  0.833333               144.40
# 8948      C19189    13.457564                  0.833333                 0.00
# 8949      C19190   372.708075                  0.666667              1093.25
#
#       oneoff_purchases  installment_purchases  amount_cash_advance  \
# 0                 0.00                  95.40             0.000000
# 1                 0.00                   0.00          6442.945483
# 2               773.17                   0.00             0.000000
# 3              1499.00                   0.00           205.788017
# 4                16.00                   0.00             0.000000
# ...                ...                    ...                  ...
# 8945              0.00                 291.12             0.000000
# 8946              0.00                 300.00             0.000000
# 8947              0.00                 144.40             0.000000
# 8948              0.00                   0.00            36.558778
# 8949           1093.25                   0.00           127.040008
#
#       purchases_frequency  oneoff_purchases_frequency  \
# 0                0.166667                    0.000000
# 1                0.000000                    0.000000
# 2                1.000000                    1.000000
# 3                0.083333                    0.083333
# 4                0.083333                    0.083333
# ...                   ...                         ...
# 8945             1.000000                    0.000000
# 8946             1.000000                    0.000000
# 8947             0.833333                    0.000000
# 8948             0.000000                    0.000000
# 8949             0.666667                    0.666667
#
#       installment_purchase_frequency  cash_advance_frequency  \
# 0                           0.083333                0.000000
# 1                           0.000000                0.250000
# 2                           0.000000                0.000000
# 3                           0.000000                0.083333
# 4                           0.000000                0.000000
# ...                              ...                     ...
# 8945                        0.833333                0.000000
# 8946                        0.833333                0.000000
# 8947                        0.666667                0.000000
# 8948                        0.000000                0.166667
# 8949                        0.000000                0.333333
#
#       cash_advance_transactions  purchase_transactions  credit_limit  \
# 0                             0                      2        1000.0
# 1                             4                      0        7000.0
# 2                             0                     12        7500.0
# 3                             1                      1        7500.0
# 4                             0                      1        1200.0
# ...                         ...                    ...           ...
# 8945                          0                      6        1000.0
# 8946                          0                      6        1000.0
# 8947                          0                      5        1000.0
# 8948                          2                      0         500.0
# 8949                          2                     23        1200.0
#
#       amount_of_payments  minimum_payments_made  pct_of_full_payments  tenure
# 0             201.802084             139.509787              0.000000      12
# 1            4103.032597            1072.340217              0.222222      12
# 2             622.066742             627.284787              0.000000      12
# 3               0.000000                    NaN              0.000000      12
# 4             678.334763             244.791237              0.000000      12
# ...                  ...                    ...                   ...     ...
# 8945          325.594462              48.886365              0.500000       6
# 8946          275.861322                    NaN              0.000000       6
# 8947           81.270775              82.418369              0.250000       6
# 8948           52.549959              55.755628              0.250000       6
# 8949           63.165404              88.288956              0.000000       6
#
# [8950 rows x 18 columns]

# %%
renamed_df.isna().sum()
# Out:
# customer_id                         0
# balance                             0
# balance_change_frequency            0
# number_of_purchases                 0
# oneoff_purchases                    0
# installment_purchases               0
# amount_cash_advance                 0
# purchases_frequency                 0
# oneoff_purchases_frequency          0
# installment_purchase_frequency      0
# cash_advance_frequency              0
# cash_advance_transactions           0
# purchase_transactions               0
# credit_limit                        1
# amount_of_payments                  0
# minimum_payments_made             313
# pct_of_full_payments                0
# tenure                              0
# dtype: int64

# %%
no_na_df=renamed_df.dropna()
no_na_df.set_index(['customer_id'],inplace = True)
no_na_df
# Out:
#                  balance  balance_change_frequency  number_of_purchases  \
# customer_id
# C10001         40.900749                  0.818182                95.40
# C10002       3202.467416                  0.909091                 0.00
# C10003       2495.148862                  1.000000               773.17
# C10005        817.714335                  1.000000                16.00
# C10006       1809.828751                  1.000000              1333.28
# ...                  ...                       ...                  ...
# C19184          5.871712                  0.500000                20.90
# C19186         28.493517                  1.000000               291.12
# C19188         23.398673                  0.833333               144.40
# C19189         13.457564                  0.833333                 0.00
# C19190        372.708075                  0.666667              1093.25
#
#              oneoff_purchases  installment_purchases  amount_cash_advance  \
# customer_id
# C10001                   0.00                  95.40             0.000000
# C10002                   0.00                   0.00          6442.945483
# C10003                 773.17                   0.00             0.000000
# C10005                  16.00                   0.00             0.000000
# C10006                   0.00                1333.28             0.000000
# ...                       ...                    ...                  ...
# C19184                  20.90                   0.00             0.000000
# C19186                   0.00                 291.12             0.000000
# C19188                   0.00                 144.40             0.000000
# C19189                   0.00                   0.00            36.558778
# C19190                1093.25                   0.00           127.040008
#
#              purchases_frequency  oneoff_purchases_frequency  \
# customer_id
# C10001                  0.166667                    0.000000
# C10002                  0.000000                    0.000000
# C10003                  1.000000                    1.000000
# C10005                  0.083333                    0.083333
# C10006                  0.666667                    0.000000
# ...                          ...                         ...
# C19184                  0.166667                    0.166667
# C19186                  1.000000                    0.000000
# C19188                  0.833333                    0.000000
# C19189                  0.000000                    0.000000
# C19190                  0.666667                    0.666667
#
#              installment_purchase_frequency  cash_advance_frequency  \
# customer_id
# C10001                             0.083333                0.000000
# C10002                             0.000000                0.250000
# C10003                             0.000000                0.000000
# C10005                             0.000000                0.000000
# C10006                             0.583333                0.000000
# ...                                     ...                     ...
# C19184                             0.000000                0.000000
# C19186                             0.833333                0.000000
# C19188                             0.666667                0.000000
# C19189                             0.000000                0.166667
# C19190                             0.000000                0.333333
#
#              cash_advance_transactions  purchase_transactions  credit_limit  \
# customer_id
# C10001                               0                      2        1000.0
# C10002                               4                      0        7000.0
# C10003                               0                     12        7500.0
# C10005                               0                      1        1200.0
# C10006                               0                      8        1800.0
# ...                                ...                    ...           ...
# C19184                               0                      1         500.0
# C19186                               0                      6        1000.0
# C19188                               0                      5        1000.0
# C19189                               2                      0         500.0
# C19190                               2                     23        1200.0
#
#              amount_of_payments  minimum_payments_made  pct_of_full_payments  \
# customer_id
# C10001               201.802084             139.509787              0.000000
# C10002              4103.032597            1072.340217              0.222222
# C10003               622.066742             627.284787              0.000000
# C10005               678.334763             244.791237              0.000000
# C10006              1400.057770            2407.246035              0.000000
# ...                         ...                    ...                   ...
# C19184                58.644883              43.473717              0.000000
# C19186               325.594462              48.886365              0.500000
# C19188                81.270775              82.418369              0.250000
# C19189                52.549959              55.755628              0.250000
# C19190                63.165404              88.288956              0.000000
#
#              tenure
# customer_id
# C10001           12
# C10002           12
# C10003           12
# C10005           12
# C10006           12
# ...             ...
# C19184            6
# C19186            6
# C19188            6
# C19189            6
# C19190            6
#
# [8636 rows x 17 columns]

# %%
no_na_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8636 entries, C10001 to C19190
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   balance                         8636 non-null   float64
#  1   balance_change_frequency        8636 non-null   float64
#  2   number_of_purchases             8636 non-null   float64
#  3   oneoff_purchases                8636 non-null   float64
#  4   installment_purchases           8636 non-null   float64
#  5   amount_cash_advance             8636 non-null   float64
#  6   purchases_frequency             8636 non-null   float64
#  7   oneoff_purchases_frequency      8636 non-null   float64
#  8   installment_purchase_frequency  8636 non-null   float64
#  9   cash_advance_frequency          8636 non-null   float64
#  10  cash_advance_transactions       8636 non-null   int64
#  11  purchase_transactions           8636 non-null   int64
#  12  credit_limit                    8636 non-null   float64
#  13  amount_of_payments              8636 non-null   float64
#  14  minimum_payments_made           8636 non-null   float64
#  15  pct_of_full_payments            8636 non-null   float64
#  16  tenure                          8636 non-null   int64
# dtypes: float64(14), int64(3)
# memory usage: 1.2+ MB

# %%
no_na_df.to_sql(name='full_credit_cards',
                        con=engine,
                        index=True,
                        if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "full_credit_cards_pkey"
# DETAIL:  Key (customer_id)=(C10001) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-37-d4b15baebf30> in <module>
#       2                         con=engine,
#       3                         index=True,
# ----> 4                         if_exists='append')
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "full_credit_cards_pkey"
# DETAIL:  Key (customer_id)=(C10001) already exists.
#
# [SQL: INSERT INTO full_credit_cards (customer_id, balance, balance_change_frequency, number_of_purchases, oneoff_purchases, installment_purchases, amount_cash_advance, purchases_frequency, oneoff_purchases_frequency, installment_purchase_frequency, cash_advance_frequency, cash_advance_transactions, purchase_transactions, credit_limit, amount_of_payments, minimum_payments_made, pct_of_full_payments, tenure) VALUES (%(customer_id)s, %(balance)s, %(balance_change_frequency)s, %(number_of_purchases)s, %(oneoff_purchases)s, %(installment_purchases)s, %(amount_cash_advance)s, %(purchases_frequency)s, %(oneoff_purchases_frequency)s, %(installment_purchase_frequency)s, %(cash_advance_frequency)s, %(cash_advance_transactions)s, %(purchase_transactions)s, %(credit_limit)s, %(amount_of_payments)s, %(minimum_payments_made)s, %(pct_of_full_payments)s, %(tenure)s)]
# [parameters: ({'customer_id': 'C10001', 'balance': 40.900749, 'balance_change_frequency': 0.818182, 'number_of_purchases': 95.4, 'oneoff_purchases': 0.0, 'installment_purchases': 95.4, 'amount_cash_advance': 0.0, 'purchases_frequency': 0.166667, 'oneoff_purchases_frequency': 0.0, 'installment_purchase_frequency': 0.083333, 'cash_advance_frequency': 0.0, 'cash_advance_transactions': 0, 'purchase_transactions': 2, 'credit_limit': 1000.0, 'amount_of_payments': 201.802084, 'minimum_payments_made': 139.50978700000002, 'pct_of_full_payments': 0.0, 'tenure': 12}, {'customer_id': 'C10002', 'balance': 3202.467416, 'balance_change_frequency': 0.909091, 'number_of_purchases': 0.0, 'oneoff_purchases': 0.0, 'installment_purchases': 0.0, 'amount_cash_advance': 6442.9454829999995, 'purchases_frequency': 0.0, 'oneoff_purchases_frequency': 0.0, 'installment_purchase_frequency': 0.0, 'cash_advance_frequency': 0.25, 'cash_advance_transactions': 4, 'purchase_transactions': 0, 'credit_limit': 7000.0, 'amount_of_payments': 4103.032596999999, 'minimum_payments_made': 1072.340217, 'pct_of_full_payments': 0.22222199999999998, 'tenure': 12}, {'customer_id': 'C10003', 'balance': 2495.148862, 'balance_change_frequency': 1.0, 'number_of_purchases': 773.17, 'oneoff_purchases': 773.17, 'installment_purchases': 0.0, 'amount_cash_advance': 0.0, 'purchases_frequency': 1.0, 'oneoff_purchases_frequency': 1.0, 'installment_purchase_frequency': 0.0, 'cash_advance_frequency': 0.0, 'cash_advance_transactions': 0, 'purchase_transactions': 12, 'credit_limit': 7500.0, 'amount_of_payments': 622.066742, 'minimum_payments_made': 627.284787, 'pct_of_full_payments': 0.0, 'tenure': 12}, {'customer_id': 'C10005', 'balance': 817.714335, 'balance_change_frequency': 1.0, 'number_of_purchases': 16.0, 'oneoff_purchases': 16.0, 'installment_purchases': 0.0, 'amount_cash_advance': 0.0, 'purchases_frequency': 0.083333, 'oneoff_purchases_frequency': 0.083333, 'installment_purchase_frequency': 0.0, 'cash_advance_frequency': 0.0, 'cash_advance_transactions': 0, 'purchase_transactions': 1, 'credit_limit': 1200.0, 'amount_of_payments': 678.334763, 'minimum_payments_made': 244.79123700000002, 'pct_of_full_payments': 0.0, 'tenure': 12}, {'customer_id': 'C10006', 'balance': 1809.8287510000002, 'balance_change_frequency': 1.0, 'number_of_purchases': 1333.28, 'oneoff_purchases': 0.0, 'installment_purchases': 1333.28, 'amount_cash_advance': 0.0, 'purchases_frequency': 0.666667, 'oneoff_purchases_frequency': 0.0, 'installment_purchase_frequency': 0.583333, 'cash_advance_frequency': 0.0, 'cash_advance_transactions': 0, 'purchase_transactions': 8, 'credit_limit': 1800.0, 'amount_of_payments': 1400.05777, 'minimum_payments_made': 2407.246035, 'pct_of_full_payments': 0.0, 'tenure': 12}, {'customer_id': 'C10007', 'balance': 627.260806, 'balance_change_frequency': 1.0, 'number_of_purchases': 7091.01, 'oneoff_purchases': 6402.63, 'installment_purchases': 688.38, 'amount_cash_advance': 0.0, 'purchases_frequency': 1.0, 'oneoff_purchases_frequency': 1.0, 'installment_purchase_frequency': 1.0, 'cash_advance_frequency': 0.0, 'cash_advance_transactions': 0, 'purchase_transactions': 64, 'credit_limit': 13500.0, 'amount_of_payments': 6354.314328, 'minimum_payments_made': 198.065894, 'pct_of_full_payments': 1.0, 'tenure': 12}, {'customer_id': 'C10008', 'balance': 1823.6527429999999, 'balance_change_frequency': 1.0, 'number_of_purchases': 436.2, 'oneoff_purchases': 0.0, 'installment_purchases': 436.2, 'amount_cash_advance': 0.0, 'purchases_frequency': 1.0, 'oneoff_purchases_frequency': 0.0, 'installment_purchase_frequency': 1.0, 'cash_advance_frequency': 0.0, 'cash_advance_transactions': 0, 'purchase_transactions': 12, 'credit_limit': 2300.0, 'amount_of_payments': 679.0650820000001, 'minimum_payments_made': 532.03399, 'pct_of_full_payments': 0.0, 'tenure': 12}, {'customer_id': 'C10009', 'balance': 1014.9264730000001, 'balance_change_frequency': 1.0, 'number_of_purchases': 861.49, 'oneoff_purchases': 661.49, 'ins ...
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
no_na_df.to_csv("pandas_etl.csv")
